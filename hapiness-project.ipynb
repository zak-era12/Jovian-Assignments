# %% [markdown]
# # The World Happiness Report of 2019

# %% [markdown]
# Happiness??? Why a mere emotion is given so much sigificance?
# Apparanetly, 'Eat, work, Sleep... Repeat' is not all that is to life and the advocacy for mental health in the recent years has highlighted what had long been disregarded as nothing.
# According to Wikipedia, the term happiness is used in the context of mental or emotional states, including positive or pleasant emotions ranging from contentment to intense joy. It is also used in the context of life satisfaction, subjective well-being, eudaimonia, flourishing and well-being.
#
# According to Dr. Ed Deiner,sustainable happiness, which is lasting, not just momentary is the one of the contributing factors to Better health and longevity, Superior work performance, especially organizational citizenship, More supportive social relationships and most importantly Better citizenship and more “prosocial” behaviors.

# %% [markdown]
# ## Initial Setup

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# !pip install numpy pandas matplotlib seaborn --upgrade --quiet

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
jovian.commit(project='happiness-project',environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Please enter your API key ( from https://jovian.ml/ ):
# API KEY: ········
# [jovian] Updating notebook "zakera12m-hanif/happiness-project" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ml/zakera12m-hanif/happiness-project
# 'https://jovian.ml/zakera12m-hanif/happiness-project'

# %%
#Saving the csv file to the jupyter directory
jovian.commit(outputs=['happiness-2019.csv'])
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "zakera12m-hanif/happiness-project" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Uploading additional outputs...
# [jovian] Committed successfully! https://jovian.ml/zakera12m-hanif/happiness-project
# 'https://jovian.ml/zakera12m-hanif/happiness-project'

# %%
jovian.commit(project='happiness-project',environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "zakera12m-hanif/happiness-project" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ml/zakera12m-hanif/happiness-project
# 'https://jovian.ml/zakera12m-hanif/happiness-project'

# %% [markdown]
# ## Loading and exploring the dataset

# %%
# Importing the raw dataset
raw_df=pd.read_csv('happiness-2019.csv')

# %%
raw_df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#Checking the columns in the df
raw_df.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#Checking the datatype of each column
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
raw_df.sample(10)
# Out:
#      Overall rank   Country or region  Score  GDP per capita  Social support  \
# 13             14          Luxembourg  7.090           1.609           1.479
# 18             19       United States  6.892           1.433           1.457
# 121           122          Mauritania  4.490           0.570           1.167
# 98             99         Ivory Coast  4.944           0.569           0.808
# 76             77  Dominican Republic  5.425           1.015           1.401
# 112           113             Namibia  4.639           0.879           1.313
# 120           121               Kenya  4.509           0.512           0.983
# 100           101              Jordan  4.906           0.837           1.225
# 150           151               Yemen  3.380           0.287           1.163
# 119           120              Gambia  4.516           0.308           0.939
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# As noted from the above, the headers for the columns contain whitespaces which could be lead to problems at the later stages of Data Analysis.
# Therefore, lets rename the columns to eliminate the whitespaces in the column name.

# %%
raw_df=raw_df.rename(columns={
    'Overall rank':'Overall_rank',
    'Country or region':'Country_or_region',   
    'GDP per capita':'GDP_per_capita',
    'Social support':'Social_support',
    'Healthy life expectancy':'Healthy_life_expectancy',
    'Freedom to make life choices':'Freedom_to_make_life_choices',
    'Perceptions of corruption':'Perceptions_of_corruption'
},inplace=False)

# %%
#Checking the datatype of each column after modification
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall_rank                  156 non-null    int64
#  1   Country_or_region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP_per_capita                156 non-null    float64
#  4   Social_support                156 non-null    float64
#  5   Healthy_life_expectancy       156 non-null    float64
#  6   Freedom_to_make_life_choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions_of_corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
r,c=raw_df.shape
print('The number of rows are', r)
print('The number of columns are',c)
# Out:
# The number of rows are 156
# The number of columns are 9

# %% [markdown]
# ## Exploratory Data Analysis and Visualisation

# %% [markdown]
# ###### What are the number of countries included in the dataset?

# %%
raw_df.Country_or_region.nunique()
# Out:
# 156

# %% [markdown]
# ###### Name the countries included in the dataset?

# %%
raw_df.Country_or_region.unique()
# Out:
# array(['Finland', 'Denmark', 'Norway', 'Iceland', 'Netherlands',
#        'Switzerland', 'Sweden', 'New Zealand', 'Canada', 'Austria',
#        'Australia', 'Costa Rica', 'Israel', 'Luxembourg',
#        'United Kingdom', 'Ireland', 'Germany', 'Belgium', 'United States',
#        'Czech Republic', 'United Arab Emirates', 'Malta', 'Mexico',
#        'France', 'Taiwan', 'Chile', 'Guatemala', 'Saudi Arabia', 'Qatar',
#        'Spain', 'Panama', 'Brazil', 'Uruguay', 'Singapore', 'El Salvador',
#        'Italy', 'Bahrain', 'Slovakia', 'Trinidad & Tobago', 'Poland',
#        'Uzbekistan', 'Lithuania', 'Colombia', 'Slovenia', 'Nicaragua',
#        'Kosovo', 'Argentina', 'Romania', 'Cyprus', 'Ecuador', 'Kuwait',
#        'Thailand', 'Latvia', 'South Korea', 'Estonia', 'Jamaica',
#        'Mauritius', 'Japan', 'Honduras', 'Kazakhstan', 'Bolivia',
#        'Hungary', 'Paraguay', 'Northern Cyprus', 'Peru', 'Portugal',
#        'Pakistan', 'Russia', 'Philippines', 'Serbia', 'Moldova', 'Libya',
# ...

# %%
raw_df.describe()
# Out:
#        Overall_rank       Score  GDP_per_capita  Social_support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %% [markdown]
# ###### Which country has the highest score for happiness? OR Which country is the happiest?

# %%
raw_df[raw_df.Score==raw_df.Score.max()]
# Out:
#    Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 0             1           Finland  7.769            1.34           1.587
#
#    Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions_of_corruption
# 0                      0.393

# %% [markdown]
# ###### Which country has the lowest score for happiness? OR Which country is the saddest?

# %%
raw_df[raw_df.Score==raw_df.Score.min()]
# Out:
#      Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 155           156       South Sudan  2.853           0.306           0.575
#
#      Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 155                    0.295                          0.01       0.202
#
#      Perceptions_of_corruption
# 155                      0.091

# %% [markdown]
# ###### What are the top 10 happiest countries in 2019?

# %%
raw_df.head(10)
# Out:
#    Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %% [markdown]
# ###### What are the least 10 happiest countries in 2019?

# %%
raw_df.tail(10)
# Out:
#      Overall_rank         Country_or_region  Score  GDP_per_capita  \
# 146           147                     Haiti  3.597           0.323
# 147           148                  Botswana  3.488           1.041
# 148           149                     Syria  3.462           0.619
# 149           150                    Malawi  3.410           0.191
# 150           151                     Yemen  3.380           0.287
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 146           0.688                    0.449                         0.026
# 147           1.145                    0.538                         0.455
# ...

# %% [markdown]
# ###### What are are the top 10 happiest countries with a greater GDP than the average ?

# %%
top10_happy_df=raw_df.sort_values('Score',ascending=False)[raw_df.GDP_per_capita>1].head(10)
top10_happy_df
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#    Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# ...

# %% [markdown]
# The gross domestic product per capita, or GDP per capita, is a measure of a country's economic output that accounts for its number of people. It divides the country's gross domestic product by its total population.
#
# It is clearly seen that there is a positive relationship between the 'Happiness Score' and 'GDP_per_capita'. The top 10 countries are also having a higher than an average GDP implying that greater economic output leads to more satisfied population

# %% [markdown]
# ###### What are the least 10 happiest countries with a greater GDP than the average ?

# %%
least10_happy_df=raw_df.sort_values('Score',ascending=False)[raw_df.GDP_per_capita>0.9].tail(10)
least10_happy_df
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 103           104             Gabon  4.799           1.057           1.183
# 105           106      South Africa  4.722           0.960           1.351
# 106           107           Albania  4.719           0.947           0.848
# 107           108         Venezuela  4.707           0.960           1.427
# 116           117              Iran  4.548           1.100           0.842
# 123           124           Tunisia  4.461           0.921           1.000
# 125           126              Iraq  4.437           1.043           0.980
# 129           130         Sri Lanka  4.366           0.949           1.265
# 136           137             Egypt  4.166           0.913           1.039
# ...

# %% [markdown]
# ###### What are the top 10 countries with a healthy life expectancy?

# %%
top_life_df=raw_df.sort_values('Healthy_life_expectancy',ascending=False).head(10)
top_life_df
# Out:
#     Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 33            34         Singapore  6.262           1.572           1.463
# 75            76         Hong Kong  5.430           1.438           1.277
# 57            58             Japan  5.886           1.327           1.419
# 29            30             Spain  6.354           1.286           1.484
# 5              6       Switzerland  7.480           1.452           1.526
# 23            24            France  6.592           1.324           1.472
# 48            49            Cyprus  6.046           1.263           1.223
# 63            64   Northern Cyprus  5.718           1.263           1.252
# 35            36             Italy  6.223           1.294           1.488
# 8              9            Canada  7.278           1.365           1.505
#
#     Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 33                    1.141                         0.556       0.271
# ...

# %% [markdown]
# This implies that there is no direct relationships between the Happiness Score and the life expectancy. A healthy life expectancy may be result of healthy and active lifestyle, good medical infrastructure and such related factors but does not result in the determing the Happiness of a country.

# %%
f,ax1 = plt.subplots(figsize =(12,10))
sns.barplot(x=top_life_df['Country_or_region'], y=top_life_df['Score'],palette="rocket", ax=ax1)
plt.xticks(rotation= 90)
plt.xlabel('Country')
plt.ylabel('Life Expectancy')
plt.title('Countries with highest life expectancy v/s their Happiness Score')
plt.show()

# %% [markdown]
# ###### What are the top 10 countries with the most freedom to make life choices?

# %%
free_df=raw_df.sort_values(by='Freedom_to_make_life_choices',ascending=False).head(10)
free_df
# Out:
#      Overall_rank     Country_or_region  Score  GDP_per_capita  \
# 40             41            Uzbekistan  6.174           0.745
# 108           109              Cambodia  4.700           0.574
# 2               3                Norway  7.554           1.488
# 20             21  United Arab Emirates  6.825           1.503
# 0               1               Finland  7.769           1.340
# 1               2               Denmark  7.600           1.383
# 3               4               Iceland  7.494           1.380
# 7               8           New Zealand  7.307           1.303
# 8               9                Canada  7.278           1.365
# 6               7                Sweden  7.343           1.387
#
#      Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 40            1.529                    0.756                         0.631
# 108           1.122                    0.637                         0.609
# ...

# %% [markdown]
# From above, we can see that the mostly countries with a higher happiness score have mostly free or independent environment. Thus implying that population with freedom to make life choices are comparatively more happy and satisfied.

# %% [markdown]
# ###### What are the top 10 countries with the highest Social Support ratio?

# %%
social_df=raw_df.sort_values(by='Social_support',ascending=False).head(10)
social_df
# Out:
#     Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 3              4           Iceland  7.494           1.380           1.624
# 0              1           Finland  7.769           1.340           1.587
# 2              3            Norway  7.554           1.488           1.582
# 1              2           Denmark  7.600           1.383           1.573
# 7              8       New Zealand  7.307           1.303           1.557
# 15            16           Ireland  7.021           1.499           1.553
# 10            11         Australia  7.228           1.372           1.548
# 86            87      Turkmenistan  5.247           1.052           1.538
# 14            15    United Kingdom  7.054           1.333           1.538
# 82            83          Mongolia  5.285           0.948           1.531
#
#     Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 3                     1.026                         0.591       0.354
# ...

# %% [markdown]
# ###### What are the countries with the most generous population?

# %%
generous_df=raw_df.sort_values(by='Generosity',ascending=False).head(10)
generous_df
# Out:
#      Overall_rank Country_or_region  Score  GDP_per_capita  Social_support  \
# 130           131           Myanmar  4.360           0.710           1.181
# 91             92         Indonesia  5.192           0.931           1.203
# 146           147             Haiti  3.597           0.323           0.688
# 21             22             Malta  6.726           1.300           1.520
# 120           121             Kenya  4.509           0.512           0.983
# 94             95            Bhutan  5.082           0.813           1.321
# 51             52          Thailand  6.008           1.050           1.409
# 3               4           Iceland  7.494           1.380           1.624
# 14             15    United Kingdom  7.054           1.333           1.538
# 10             11         Australia  7.228           1.372           1.548
#
#      Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# ...

# %% [markdown]
# Here the most generous countries do not sport a really good happiness score signalling to the fact that  Generosity does not have any relationship in determining how happy a countries population is.

# %%
# showing country-wise ranking of happiness score
plt.rcParams['figure.figsize']=(20,50)
sns.barplot(raw_df['Score'], raw_df['Country_or_region'])
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,40))
plt.plot (raw_df.Score, raw_df.Country_or_region, marker ='o' ,color ='blue' , ls = '-' , mfc = 'red')
plt.xlabel('Score')
plt.ylabel('Countries')
plt.title('Countries v/s Score')
# Out:
# Text(0.5, 1.0, 'Countries v/s Score')

# %% [markdown]
# ## Correlation matrix
# A correlation coefficient measures the extent to which two variables tend to change together. The coefficient describes both the strength and the direction of the relationship.
# A correlation matrix (usually meaning the Pearson method) is a table showing correlation coefficients between variables. Each cell in the table shows the correlation between two variables. A correlation matrix is used to summarize data, as an input into a more advanced analysis, and as a diagnostic for advanced analyses.
#
# In pandas, the corr() computes pairwise correlation of columns, excluding NA/null values.

# %%
raw_df.corr()
# Out:
#                               Overall_rank     Score  GDP_per_capita  \
# Overall_rank                      1.000000 -0.989096       -0.801947
# Score                            -0.989096  1.000000        0.793883
# GDP_per_capita                   -0.801947  0.793883        1.000000
# Social_support                   -0.767465  0.777058        0.754906
# Healthy_life_expectancy          -0.787411  0.779883        0.835462
# Freedom_to_make_life_choices     -0.546606  0.566742        0.379079
# Generosity                       -0.047993  0.075824       -0.079662
# Perceptions_of_corruption        -0.351959  0.385613        0.298920
#
#                               Social_support  Healthy_life_expectancy  \
# Overall_rank                       -0.767465                -0.787411
# Score                               0.777058                 0.779883
# GDP_per_capita                      0.754906                 0.835462
# ...

# %% [markdown]
# Although this gives us the correlation between columns in our dataset it is hard to read and understand. So, lets plot it using Seaborn.

# %%
f,ax=plt.subplots(figsize=(10,9))
sns.heatmap(raw_df.corr(), 
            annot=True,fmt='.2f', ax=ax, vmin=-1, vmax=1,
            center=0, linewidths=3, linecolor='black',
           cmap='YlGnBu')
plt.show()

# %% [markdown]
# In the Heat Map generated above, we can see that economy,family and health are highly correlated with happiness score and also we can see that generosity has low relationship with happiness score.

# %% [markdown]
# ## Spearman Correlation Matrix

# %% [markdown]
# The Spearman's rank-order correlation is the nonparametric version of the Pearson product-moment correlation. Spearman's correlation coefficient, (ρ, also signified by rs) measures the strength and direction of association between two ranked variables.
# One difference between Spearman Correlatio Matrix and Pearson Correlation Matrix  is that Pearson works with raw data values of the variables whereas Spearman works with rank-ordered variables. Now, if we feel that a scatterplot is visually indicating a “might be monotonic, might be linear” relationship, our best bet would be to apply Spearman and not Pearson

# %%
spearman_cormatrix= raw_df.corr(method='spearman')
spearman_cormatrix
# Out:
#                               Overall_rank     Score  GDP_per_capita  \
# Overall_rank                      1.000000 -0.999999       -0.814430
# Score                            -0.999999  1.000000        0.814483
# GDP_per_capita                   -0.814430  0.814483        1.000000
# Social_support                   -0.816125  0.816181        0.768539
# Healthy_life_expectancy          -0.807279  0.807275        0.851513
# Freedom_to_make_life_choices     -0.552014  0.551974        0.393426
# Generosity                       -0.070484  0.070483       -0.041304
# Perceptions_of_corruption        -0.217240  0.217348        0.223203
#
#                               Social_support  Healthy_life_expectancy  \
# Overall_rank                       -0.816125                -0.807279
# Score                               0.816181                 0.807275
# GDP_per_capita                      0.768539                 0.851513
# ...

# %%
fig, ax = plt.subplots(ncols=2,figsize=(24, 8))
sns.heatmap(spearman_cormatrix, vmin=-1, vmax=1, ax=ax[0], center=0, cmap="cividis", annot=True)
sns.heatmap(spearman_cormatrix, vmin=-.25, vmax=1, ax=ax[1], center=0, cmap="viridis", annot=True)
# Out:
# <AxesSubplot:>

# %%
raw_df['GDP_per_capita'].plot(kind = "line", color = "purple",label = "Economy (GDP per Capita)",linewidth = 1, alpha = 0.5, grid = True,figsize=(10,6), marker='s', ms=10)
raw_df['Healthy_life_expectancy'].plot( color = "red",label = "Health (Life Expectancy)",linewidth = 1, alpha = 0.5, grid = True,figsize=(12,6), marker='o', ms=10)
plt.legend(loc='upper right')
plt.xlabel('Economy')
plt.ylabel('Life Expectancy')
plt.title('Economy vs Life Expectancy, 2015')
plt.show()

# %% [markdown]
# It clearly depicts the economy is also an crucial factor in determining the happiness score of any country.

# %% [markdown]
# ###### Does there exists any relationship between factors like 'Happiness Score' and 'Health'? If so, of what type is this relationship?

# %%
raw_df.plot(kind='scatter', x="Score", y="Healthy_life_expectancy")
plt.xlabel('Happiness Score')
plt.ylabel('Health')
plt.title('Happiness Score vs Health')
plt.show()

# %% [markdown]
# It is clear from this graph that higher happiness does relate to having a healthier life expectancy ratio meaning that there is a positive relationship between them.

# %% [markdown]
# ## Interesting Insights and Conclusion
# 1. Mostly countries from continents like Europe and Zealandia are included in the top 10 happiest countries.Therefore, mostly Europeans and Zealanders are the happiest.
# 2. This also leads to the fact that all the top 10 countries are developed countries.
# 3. Mostly countries from continents like Africa and Asia are included in the least 10 happiest countries.Therefore, mostly Africans and Asians are the least happy.
# 4. This also leads to the fact that all the top 10 countries are underdeveloped countries and have population living below poverty line.
# 5. Hence, it can said from the aforementioned inferences that the level of development in a country is also a major contributor to the lifestyle of population and therefore affects their emotional health as well.

# %% [markdown]
# ## References
# 1. Definition of Happiness- https://en.wikipedia.org/wiki/Happiness
#
# 2. Importance of Happiness- https://greatergood.berkeley.edu/article/item/why_governments_should_care_more_about_happiness
#
# 3. Numpy Documentation- https://numpy.org/devdocs/user/quickstart.html
#
# 4. Pandas Documentation-https://pandas.pydata.org/docs/user_guide/index.html
#
# 5. Seaborn Documentation- https://seaborn.pydata.org/examples/index.html
#
# 6. Matplotlib Documentation- https://matplotlib.org/3.1.1/gallery/index.html
#
# 7. World Happiness Dataset- https://www.kaggle.com/unsdsn/world-happiness?select=2019.csv
#
# 8. How happy are we?- https://www.kaggle.com/helingnc/world-happiness-dataset-my-first-kernel

# %%
jovian.commit(project='happiness-project',environment=None)
# Out:
# [jovian] Attempting to save notebook..
